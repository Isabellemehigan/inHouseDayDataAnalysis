# %% [markdown]
# # 🏛️ Auction House Data Analysis
#
# This notebook explores two datasets from an auction house:
#
# | File | Contents |
# |------|----------|
# | `Auctions_and_contacts.xlsx` | **Auction Items** (137 lots), **Contacts** (155 buyers/sellers), **Auction Details** (6 events) |
# | `Full_Catalog.xlsx` | **Full Catalog** (137 objects with descriptions and catalog prices) |
#
# Work through the guided sections, then tackle the open-ended challenges at the end.

# %% [markdown]
# ## 0. Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns

# Consistent visual style
sns.set_theme(style='whitegrid', palette='muted')
plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['figure.dpi'] = 110

print('Libraries loaded ✓')

# %% [markdown]
# ## 1. Load the Data

# %%
# ── Auctions_and_contacts ──────────────────────────────────────────────────
items    = pd.read_excel('Auctions_and_contacts__1_.xlsx', sheet_name='Auction Items')
contacts = pd.read_excel('Auctions_and_contacts__1_.xlsx', sheet_name='Contacts')
auctions = pd.read_excel('Auctions_and_contacts__1_.xlsx', sheet_name='Auction Details')

# ── Full_Catalog ───────────────────────────────────────────────────────────
catalog  = pd.read_excel('Full_Catalog__1_.xlsx', sheet_name='Page 1')

print(f'Auction Items : {items.shape}')
print(f'Contacts      : {contacts.shape}')
print(f'Auction Details: {auctions.shape}')
print(f'Full Catalog  : {catalog.shape}')

# %% [markdown]
# ## 2. First Look at Each Table
#
# Before any analysis, always inspect your data. Run each cell and note:
# - What are the column names and types?
# - Are there any missing values?
# - Do the values look sensible?

# %%
print('=== Auction Items ===')
print(items.dtypes)
print()
items.head()

# %%
print('=== Contacts ===')
print(contacts.dtypes)
print()
contacts.head()

# %%
print('=== Auction Details ===')
auctions

# %%
print('=== Full Catalog ===')
print(catalog.dtypes)
print()
catalog.head()

# %% [markdown]
# ## 3. Data Quality Check

# %%
# Missing values in each table
for name, df in [('Auction Items', items), ('Contacts', contacts),
                 ('Auction Details', auctions), ('Catalog', catalog)]:
    missing = df.isnull().sum()
    if missing.any():
        print(f'\n{name} — missing values:')
        print(missing[missing > 0])
    else:
        print(f'{name} — no missing values ✓')

# %%
# Lots where Sold_for == 0 are unsold
unsold = items[items['Sold_for'] == 0]
sold   = items[items['Sold_for'] > 0]

print(f'Total lots  : {len(items)}')
print(f'Sold        : {len(sold)}  ({len(sold)/len(items)*100:.1f}%)')
print(f'Unsold      : {len(unsold)}  ({len(unsold)/len(items)*100:.1f}%)')

# %% [markdown]
# ## 4. Joining the Tables
#
# The real power comes from combining tables.
# `Object_id` links **Auction Items** ↔ **Full Catalog**.
# `Auction_id` links **Auction Items** ↔ **Auction Details**.

# %%
# Join items with catalog to get descriptions and catalog prices
merged = items.merge(catalog, on='Object_id', how='left')

# Join with auction details
merged = merged.merge(
    auctions.rename(columns={'Auction': 'Auction_id'}),
    on='Auction_id',
    how='left'
)

print(f'Merged table shape: {merged.shape}')
merged.head(3)

# %%
# Add a column: did the item beat its catalog price?
sold_only = merged[merged['Sold_for'] > 0].copy()
sold_only['above_catalog'] = sold_only['Sold_for'] > sold_only['CatalogPrice']
sold_only['hammer_vs_catalog_pct'] = (
    (sold_only['Sold_for'] - sold_only['CatalogPrice']) / sold_only['CatalogPrice'] * 100
).round(1)

print(f"Items that sold above catalog price: {sold_only['above_catalog'].sum()} "
      f"({sold_only['above_catalog'].mean()*100:.1f}%)")
sold_only[['Object_id', 'ObjectDescription', 'CatalogPrice', 'Sold_for',
           'hammer_vs_catalog_pct']].head(8)

# %% [markdown]
# ## 5. Summary Statistics

# %%
print('=== Sold lots — price summary ===')
sold_only[['Start_Bid', 'CatalogPrice', 'Sold_for']].describe().applymap(
    lambda x: f'${x:,.0f}' if pd.notna(x) else x
)

# %%
# Revenue per auction
revenue = (
    merged[merged['Sold_for'] > 0]
    .groupby('Auction_name')['Sold_for']
    .agg(lots_sold='count', total_revenue='sum', avg_hammer='mean')
    .sort_values('total_revenue', ascending=False)
)
revenue['total_revenue'] = revenue['total_revenue'].map('${:,.0f}'.format)
revenue['avg_hammer']    = revenue['avg_hammer'].map('${:,.0f}'.format)
revenue

# %% [markdown]
# ## 6. Visualisations

# %%
# ── 6a. Hammer price distribution (sold lots) ─────────────────────────────
fig, ax = plt.subplots()
ax.hist(sold_only['Sold_for'], bins=30, edgecolor='white', color='steelblue')
ax.set_title('Distribution of Hammer Prices (sold lots)')
ax.set_xlabel('Hammer Price ($)')
ax.set_ylabel('Number of lots')
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x:,.0f}'))
plt.tight_layout()
plt.show()

print('\nNote: the distribution is heavily right-skewed — a few very high-value '
      'lots pull the mean well above the median.')

# %%
# ── 6b. Catalog price vs hammer price ────────────────────────────────────
fig, ax = plt.subplots()
ax.scatter(
    sold_only['CatalogPrice'],
    sold_only['Sold_for'],
    alpha=0.6, edgecolors='white', linewidth=0.4, color='coral'
)
# 45-degree line = sold exactly at catalog price
lim = max(sold_only['CatalogPrice'].max(), sold_only['Sold_for'].max())
ax.plot([0, lim], [0, lim], 'k--', linewidth=1, label='Sold at catalog price')
ax.set_title('Catalog Price vs Hammer Price')
ax.set_xlabel('Catalog Price ($)')
ax.set_ylabel('Hammer Price ($)')
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x/1e6:.1f}M' if x >= 1e6 else f'${x:,.0f}'))
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x/1e6:.1f}M' if x >= 1e6 else f'${x:,.0f}'))
ax.legend()
plt.tight_layout()
plt.show()

# %%
# ── 6c. Total revenue by auction ─────────────────────────────────────────
rev_plot = (
    merged[merged['Sold_for'] > 0]
    .groupby('Auction_name')['Sold_for']
    .sum()
    .sort_values(ascending=True)
)

fig, ax = plt.subplots(figsize=(10, 4))
rev_plot.plot(kind='barh', ax=ax, color='mediumseagreen', edgecolor='white')
ax.set_title('Total Hammer Revenue by Auction')
ax.set_xlabel('Total Revenue ($)')
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x/1e6:.1f}M'))
plt.tight_layout()
plt.show()

# %%
# ── 6d. Buyer geography ───────────────────────────────────────────────────
buyer_ids = sold_only['Buyer_ID'].dropna().astype(int)
buyers = contacts[contacts['Contact _ID'].isin(buyer_ids)]

country_counts = buyers['Country'].value_counts().head(10)

fig, ax = plt.subplots()
country_counts.plot(kind='bar', ax=ax, color='slateblue', edgecolor='white')
ax.set_title('Top 10 Buyer Countries')
ax.set_xlabel('Country')
ax.set_ylabel('Number of buyers')
ax.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Top Performers

# %%
# Top 10 lots by hammer price
top10 = (
    sold_only
    .nlargest(10, 'Sold_for')
    [['ObjectDescription', 'Auction_name', 'CatalogPrice', 'Sold_for', 'hammer_vs_catalog_pct']]
    .reset_index(drop=True)
)
top10.index += 1  # 1-indexed
top10['CatalogPrice'] = top10['CatalogPrice'].map('${:,.0f}'.format)
top10['Sold_for']     = top10['Sold_for'].map('${:,.0f}'.format)
top10['hammer_vs_catalog_pct'] = top10['hammer_vs_catalog_pct'].map('{:+.1f}%'.format)
top10

# %%
# Most active buyers (by number of lots purchased)
buyer_activity = (
    sold_only
    .groupby('Buyer_ID')
    .agg(lots_bought=('Object_id', 'count'), total_spend=('Sold_for', 'sum'))
    .sort_values('lots_bought', ascending=False)
    .head(10)
    .reset_index()
)
buyer_activity['Buyer_ID'] = buyer_activity['Buyer_ID'].astype(int)
buyer_activity = buyer_activity.merge(
    contacts.rename(columns={'Contact _ID': 'Buyer_ID'})[['Buyer_ID', 'First_Name', 'Last_name', 'Country']],
    on='Buyer_ID', how='left'
)
buyer_activity['total_spend'] = buyer_activity['total_spend'].map('${:,.0f}'.format)
buyer_activity

# %% [markdown]
# ---
# ## 🔍 Student Challenges
#
# Now it's your turn. Use the tables and tools above to explore the following questions.
# There is no single right answer — focus on being systematic and explaining your findings.
#
# ### Challenge 1 — Unsold lots
# Which lots failed to sell? Is there a pattern in their catalog prices or starting bids compared to lots that did sell? Visualise the difference.
#
# ### Challenge 2 — Seller analysis
# Who are the most active sellers? Do certain sellers consistently achieve prices above or below catalog estimates?
#
# ### Challenge 3 — Auction performance over time
# The `Auction Details` sheet has dates. Does revenue or sell-through rate change over time? Are there seasonal patterns?
#
# ### Challenge 4 — Starting bid strategy
# Is there a relationship between starting bid and final hammer price? Do lower starting bids lead to higher final prices (the "low estimate" strategy used by many auction houses)?
#
# ### Challenge 5 — Geography
# Which countries produce the highest-spending buyers on average? Are certain nationalities drawn to higher-value lots?
#
# ### Challenge 6 — Object type (open-ended)
# Look at the `ObjectDescription` column in the catalog. Can you group objects into categories (paintings, photographs, books, etc.) using string matching? Does category affect sell-through rate or premium over catalog estimate?
#
# > **Tip:** Use `catalog['ObjectDescription'].str.contains(...)` to filter by keyword, or try `str.split` and `value_counts()` to find common words.

# %%
# Your code here ↓
